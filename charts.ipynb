# %% [markdown]
# # GRÁFICOS

# %%
# %%
import sqlite3
import pandas as pd
import plotly.express as px
import plotly.io as pio
import re

pio.renderers.default = "notebook_connected"

DATABASE_NAME = "internet_governance_news.db"

def load_articles():
    conn = sqlite3.connect(DATABASE_NAME)
    df = pd.read_sql("SELECT * FROM articles", conn)
    conn.close()
    return df

df_all = load_articles()
print(f"📦 Total de registros no banco: {len(df_all)}")
df_all.head()
# Out:
# 📦 Total de registros no banco: 3523
#     id                                              title         date  \
# 0  610  50 milhões de brasileiros já usam IA, mas pote...  09 DEZ 2025
# 1  611  15ª Semana de Infraestrutura da Internet debat...  09 DEZ 2025
# 2  612  NIC.br celebra 20 anos de atuação pelo desenvo...  05 DEZ 2025
# 3  613  No Dia Internacional da Pessoa com Deficiência...  03 DEZ 2025
# 4  614  Estudo do Cetic.br revela demanda por formação...   2025-11-25
#
#             author                                                url  \
# 0  CGI.br Notícias  https://cgi.br/noticia/releases/50-milhoes-de-...
# 1  CGI.br Notícias  https://cgi.br/noticia/releases/15-semana-de-i...
# 2  CGI.br Notícias  https://cgi.br/noticia/releases/nic-br-celebra...
# 3  CGI.br Notícias  https://cgi.br/noticia/releases/no-dia-interna...
# 4  CGI.br Notícias  https://cgi.br/noticia/releases/estudo-do-ceti...
#
#          source
# 0  CGI Notícias
# 1  CGI Notícias
# 2  CGI Notícias
# 3  CGI Notícias
# 4  CGI Notícias

# %% [markdown]
# ### Preparo das datas

# %%
# %%
df_time = df_all.copy()

df_time["date_clean"] = pd.to_datetime(
    df_time["date"].str.extract(r"(\d{2}/\d{2}/\d{4})")[0],
    dayfirst=True,
    errors="coerce"
)

df_time = df_time.dropna(subset=["date_clean"])

print(f"⏱️ Registros com data válida: {len(df_time)}")
# Out:
# ⏱️ Registros com data válida: 1279

# %% [markdown]
# ### Contagem de notícias por fonte (6 SITES)

# %%
df_all["source"].value_counts()
# Out:
# source
# European Commission     899
# CGI Notícias            836
# Câmara dos Deputados    778
# NIC Notícias            499
# Senado Federal          329
# Agência Senado          172
# CGI Reuniões             10
# Name: count, dtype: int64

# %% [markdown]
# ### Gráfico de Pizza (TODAS as fontes)

# %%
source_counts = df_all["source"].value_counts().reset_index()
source_counts.columns = ["source", "count"]

px.pie(
    source_counts,
    names="source",
    values="count",
    title="Distribuição de Notícias por Fonte (Todos os Sites)"
).show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="3a48ac77-a2e1-4bd7-adcb-3e9d2334f7f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3a48ac77-a2e1-4bd7-adcb-3e9d2334f7f3")) {                    Plotly.newPlot(                        "3a48ac77-a2e1-4bd7-adcb-3e9d2334f7f3",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"source=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["European Commission","CGI Not\u00edcias","C\u00e2mara dos Deputados","NIC Not\u00edcias","Senado Federal","Ag\u00eancia Senado","CGI Reuni\u00f5es"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i2","bdata":"gwNEAwoD8wFJAawACgA="},"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlin ...

# %% [markdown]
# ### Total de notícias ao longo do tempo

# %%
timeline = (
    df_time["date_clean"]
    .value_counts()
    .sort_index()
    .reset_index()
)

timeline.columns = ["data", "quantidade"]

px.line(
    timeline,
    x="data",
    y="quantidade",
    title="Total de Notícias ao Longo do Tempo"
).show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="43dc36fa-82b3-48a7-a02b-1024980438ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("43dc36fa-82b3-48a7-a02b-1024980438ac")) {                    Plotly.newPlot(                        "43dc36fa-82b3-48a7-a02b-1024980438ac",                        [{"hovertemplate":"data=%{x}\u003cbr\u003equantidade=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2003-09-15T00:00:00.000000000","2003-09-22T00:00:00.000000000","2003-09-29T00:00:00.000000000","2003-10-04T00:00:00.000000000","2003-10-13T00:00:00.000000000","2003-10-19T00:00:00.000000000","2003-10-27T00:00:00.000000000","2003-11-02T00:00:00.000000000","2003-11-09T00:00:00.000000000","2003-11-16T00:00:00.000000000","2003-11-23T00:00:00.000000000","2003-11-30T00:00:00.000000000","2003-12-05T00:00:00.000000000","2003-12-14T00:00:00.000000000","2004-01-25T00:00:00.000000000","2004-02-01T00:00:00.000000000","2004-02-08T00:00:00.000000000","2004-02-16T00:00:00.000000000","2004-03-01T00:00:00.000000000","2004-03-08T00:00:00.000000000","2004-03-15T00:00:00.000000000","2004-03-22T00:00:00.000000000","2004-03-29T00:00:00.000000000","2004-04-05T00:00:00.000000000","2004-04-12T00:00:00.000000000","2004-04-19T00:00:00.000000000","2004-04-26T00:00:00.000000000","2004-05-03T00:00:00.000000000","2004-05-10T00:00:00.000000000","2004-05-17T00:00:00.000000000","2004-05-24T00:00:00.000000000","2004-05-31T00:00:00.000000000","2004-06-07T00:00:00.000000000","2004-06-14T00:00:00.000000000","2004-06-21T00:00:00.000000000","2004-06-28T00:00:00.000000000","2004-07-05T00:00:00.000000000","2004-07-12T00:00:00.000000000","2004-08-02T00:00:00.000000000","2004-08-09T00:00:00.000000000","2004-08-16T00:00:00.000000000","2004-08-23T00:00:00.000000000","2004-08-30T00:00:00.000000000","2004-09-06T00:00:00.000000000","2004-09-13T00:00:00.000000000","2004-09-20T00:00:00.000000000","2004-09-27T00:00:00.000000000","2004-10-04T00:00:00.000000000","2004-10-11T00:00:00.000000000","2004-10-18T00:00:00.000000000","2004-10-25T00:00:00.000000000","2004-11-07T00:00:00.000000000","2004-11-14T00:00:00.000000000","2004-11-21T00:00:00.000000000","2004-11-28T00:00:00.000000000","2004-12-05T00:00:00.000000000","2004-12-19T00:00:00.000000000","2005-02-13T00:00:00.000000000","2005-02-21T00:00:00.000000000","2005-02-28T00:00:00.000000000","2005-03-07T00:00:00.000000000","2005-03-14T00:00:00.000000000","2005-03-21T00:00:00.000000000","2005-03-28T00:00:00.000000000","2005-04-04T00:00:00.000000000","2005-04-11T00:00:00.000000000","2005-04-18T00:00:00.000000000","2005-04-25T00:00:00.000000000","2005-05-02T00:00:00.000000000","2005-05-09T00:00:00.000000000","2005-05-16T00:00:00.000000000","2005-05-23T00:00:00.000000000","2005-05-30T00:00:00.000000000","2005-06-06T00:00:00.000000000","2005-06-13T00:00:00.000000000","2005-06-20T00:00:00.000000000","2005-06-27T00:00:00.000000000","2005-07-04T00:00:00.000000000","2005-07-11T00:00:00.000000000","2005-07-18T00:00:00.000000000","2005-07-25T00:00:00.000000000","2005-08-01T00:00:00.000000000","2005-08-08T00:00:00.000000000","2005-08-15T00:00:00.000000000","2005-08-22T00:00:00.000000000","2005-08-29T00:00:00.000000000","2005-09-05T00:00:00.000000000","2005-09-12T00:00:00.000000000","2005-09-19T00:00:00.000000000","2005-09-26T00:00:00.000000000","2005-10-03T00:00:00.000000000","2005-10-10T00:00:00.000000000","2005-10-16T00:00:00.000000000","2005-10-23T00:00:00.000000000","2005-10-30T00:00:00.000000000","2005-11-06T00:00:00.000000000","2005-11-13T00:00:00.000000000","2005-11-20T00:0 ...

# %% [markdown]
# ### Top 15 notícias mais recentes

# %%
# %%
top15 = (
    df_time.sort_values("date_clean", ascending=False)
           .head(15)
           .copy()
)

top15["ordem"] = range(1, len(top15) + 1)

px.bar(
    top15,
    x="ordem",
    y="title",
    orientation="h",
    title="Top 15 Notícias Mais Recentes"
).show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="aa7ff70e-3858-4dd2-8841-e051461f8585" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("aa7ff70e-3858-4dd2-8841-e051461f8585")) {                    Plotly.newPlot(                        "aa7ff70e-3858-4dd2-8841-e051461f8585",                        [{"hovertemplate":"ordem=%{x}\u003cbr\u003etitle=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCgsMDQ4P"},"xaxis":"x","y":["CDH prop\u00f5e a\u00e7\u00f5es de apoio a m\u00e3es acusadas de sequestro internacional de filhos","Aprovada inclus\u00e3o da pol\u00edcia cient\u00edfica entre \u00f3rg\u00e3os de seguran\u00e7a p\u00fablica","Paim destaca aprova\u00e7\u00e3o de projeto contra devedores contumazes","PEC da pol\u00edcia cient\u00edfica segue para a C\u00e2mara","Regulamenta\u00e7\u00e3o do exerc\u00edcio profissional de acupuntura segue para san\u00e7\u00e3o","Vai a promulga\u00e7\u00e3o acordo com a Pol\u00f4nia sobre informa\u00e7\u00f5es classificadas","Aprovado projeto que libera im\u00f3veis da Previd\u00eancia para fins sociais","Medida provis\u00f3ria contra o tarifa\u00e7o perde a validade","CACs relatam dificuldades com PF ap\u00f3s mudan\u00e7a no controle de armas","Comiss\u00e3o vota MP da prote\u00e7\u00e3o de dados nesta quarta","Sess\u00e3o homenageia dom Pedro II e destaca legado do imperador","CACs relatam dificuldades ap\u00f3s mudan\u00e7a do registro de armas para a PF","Comiss\u00e3o vota na quarta MP que cria Ag\u00eancia Nacional de Prote\u00e7\u00e3o de Dados","CPI do Crime Organizado ouve nesta quarta o governador de Santa Catarina","Izalci defende educa\u00e7\u00e3o como base da seguran\u00e7a p\u00fablica"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0. ...

# %% [markdown]
# ### Nuvem de palavras (títulos – TODOS os sites)

# %%
# %%
text = " ".join(df_all["title"].astype(str)).lower()
words = re.findall(r"\b\w{4,}\b", text)

word_freq = (
    pd.Series(words)
    .value_counts()
    .head(20)
    .reset_index()
)

word_freq.columns = ["palavra", "frequencia"]

px.treemap(
    word_freq,
    path=["palavra"],
    values="frequencia",
    title="Palavras Mais Frequentes nos Títulos (Todos os Sites)"
).show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="d8c556b1-a025-452d-822e-3b9e961f8321" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d8c556b1-a025-452d-822e-3b9e961f8321")) {                    Plotly.newPlot(                        "d8c556b1-a025-452d-822e-3b9e961f8321",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003efrequencia=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["para","internet","sobre","c\u00e2mara","brasil","congresso","digital","european","nacional","commission","recebe","pelo","debate","lan\u00e7a","f\u00f3rum","ilumina\u00e7\u00e3o","rules","governan\u00e7a","anos","dados"],"labels":["para","internet","sobre","c\u00e2mara","brasil","congresso","digital","european","nacional","commission","recebe","pelo","debate","lan\u00e7a","f\u00f3rum","ilumina\u00e7\u00e3o","rules","governan\u00e7a","anos","dados"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":{"dtype":"f8","bdata":"AAAAAACogUAAAAAAAPB7QAAAAAAA8HdAAAAAAACQd0AAAAAAANB0QAAAAAAAEHFAAAAAAACgZkAAAAAAAGBjQAAAAAAAwF9AAAAAAAAAXUAAAAAAAABdQAAAAAAAAFxAAAAAAADAWkAAAAAAAABaQAAAAAAAQFhAAAAAAABAWEAAAAAAAEBVQAAAAAAAQFRAAAAAAADAU0AAAAAAAMBTQA=="},"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[ ...

# %% [markdown]
# ### Comparação direta entre fontes específicas

# %%
# %%
compare = (
    df_all["source"]
    .value_counts()
    .reset_index()
)

compare.columns = ["fonte", "quantidade"]

px.bar(
    compare,
    x="fonte",
    y="quantidade",
    title="Comparação de Volume de Notícias por Fonte"
).show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="0a4cbcb8-636f-4e7e-af65-d98a69eb3e87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0a4cbcb8-636f-4e7e-af65-d98a69eb3e87")) {                    Plotly.newPlot(                        "0a4cbcb8-636f-4e7e-af65-d98a69eb3e87",                        [{"hovertemplate":"fonte=%{x}\u003cbr\u003equantidade=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["European Commission","CGI Not\u00edcias","C\u00e2mara dos Deputados","NIC Not\u00edcias","Senado Federal","Ag\u00eancia Senado","CGI Reuni\u00f5es"],"xaxis":"x","y":{"dtype":"i2","bdata":"gwNEAwoD8wFJAawACgA="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"} ...
