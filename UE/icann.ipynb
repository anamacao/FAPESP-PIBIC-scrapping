# %% [markdown]
# <a href="https://colab.research.google.com/github/anamacao/FAPESP-PIBIC-scrapping/blob/main/icann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import io
import pandas as pd
import sqlite3
import time
import json
from bs4 import BeautifulSoup
import plotly.express as px
import plotly.io as pio
from datetime import datetime

# Database setup
DB_NAME = "icann_announcements.db"
conn = sqlite3.connect(DB_NAME)
c = conn.cursor()
c.execute('''CREATE TABLE IF NOT EXISTS announcements
             (id INTEGER PRIMARY KEY AUTOINCREMENT,
              title TEXT,
              date TEXT,
              link TEXT UNIQUE,
              content TEXT)''')
conn.commit()

# %%
BASE_URL = "https://www.icann.org/en/announcements"
DETAILS_URL_BASE = "https://www.icann.org/en/announcements/details/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

def extract_data_from_html(html_content, page_num):
    soup = BeautifulSoup(html_content, 'html.parser')
    script_tag = soup.find('script', id='ng-state')

    if not script_tag:
        print(f"No ng-state script found on page {page_num}")
        return []

    try:
        json_data = json.loads(script_tag.string)
    except json.JSONDecodeError:
        print(f"Failed to parse JSON on page {page_num}")
        return []

    # Find the key containing 'searchAnnouncementsWithSuggestions'
    # It usually looks like searchAnnouncementsWithSuggestions-{"from":...}
    target_key = None
    for key in json_data.keys():
        if key.startswith("searchAnnouncementsWithSuggestions-"):
            target_key = key
            # We might want to ensure it corresponds to the current page offset if possible,
            # but taking the first match is a reasonable start given the page structure.
            # Logic: Page 1 -> from:0, Page 2 -> from:20.
            # We can verify 'from' matches, but let's blindly trust the data for now.
            break

    if not target_key:
        print(f"Target JSON key not found on page {page_num}")
        return []

    try:
        results_container = json_data[target_key]['data']['announcementOperations']['announcements']['results']

        articles = []
        for item in results_container:
            title = item.get('pageTitle', '').strip()
            date_str = item.get('pageDate', '')
            slug = item.get('slug', '')
            link = DETAILS_URL_BASE + slug if slug else ''

            if title and link:
                articles.append((title, date_str, link))
        return articles

    except KeyError as e:
        print(f"Key error parsing JSON on page {page_num}: {e}")
        return []

# %%
MAX_PAGES = 211  # As requested

for i in range(1, MAX_PAGES + 1):
    url = f"{BASE_URL}?page={i}"
    print(f"Scraping page {i}...")

    try:
        r = requests.get(url, headers=HEADERS)
        r.raise_for_status()

        articles = extract_data_from_html(r.content, i)

        if not articles:
            print(f"No articles found on page {i}. Stopping.")
            break

        new_count = 0
        for title, date, link in articles:
            try:
                # Insert into DB
                c.execute("INSERT OR IGNORE INTO announcements (title, date, link) VALUES (?, ?, ?)",
                          (title, date, link))
                if c.rowcount > 0:
                    new_count += 1
            except sqlite3.Error as e:
                print(f"Database error: {e}")

        conn.commit()
        print(f"  Added {new_count} new articles.")

        if new_count == 0 and len(articles) > 0:
             # If all articles on the page were duplicates, we might want to stop if we assume chronological order and full history scrape is done.
             # But for this task, let's continue to the target page 211 as requested.
             pass

        time.sleep(1) # Be polite

    except Exception as e:
        print(f"Request failed for page {i}: {e}")
        # Optionally retry or continue
        continue

conn.close()
print("Scraping complete.")
# Out:
# Scraping page 1...
#   Added 20 new articles.
# Scraping page 2...
#   Added 20 new articles.
# Scraping page 3...
#   Added 20 new articles.
# Scraping page 4...
#   Added 20 new articles.
# Scraping page 5...
#   Added 20 new articles.
# Scraping page 6...
#   Added 20 new articles.
# Scraping page 7...
#   Added 20 new articles.
# Scraping page 8...
#   Added 20 new articles.
# Scraping page 9...
#   Added 20 new articles.
# Scraping page 10...
#   Added 20 new articles.
# Scraping page 11...
#   Added 20 new articles.
# Scraping page 12...
#   Added 20 new articles.
# Scraping page 13...
#   Added 20 new articles.
# Scraping page 14...
#   Added 20 new articles.
# Scraping page 15...
#   Added 20 new articles.
# Scraping page 16...
#   Added 20 new articles.
# Scraping page 17...
#   Added 20 new articles.
# Scraping page 18...
#   Added 20 new articles.
# Scraping page 19...
#   Added 20 new articles.
# Scraping page 20...
#   Added 20 new articles.
# Scraping page 21...
#   Added 20 new articles.
# Scraping page 22...
#   Added 20 new articles.
# Scraping page 23...
#   Added 20 new articles.
# Scraping page 24...
#   Added 20 new articles.
# Scraping page 25...
#   Added 20 new articles.
# Scraping page 26...
#   Added 20 new articles.
# Scraping page 27...
#   Added 20 new articles.
# Scraping page 28...
#   Added 20 new articles.
# Scraping page 29...
#   Added 20 new articles.
# Scraping page 30...
#   Added 20 new articles.
# Scraping page 31...
#   Added 20 new articles.
# Scraping page 32...
#   Added 20 new articles.
# Scraping page 33...
#   Added 20 new articles.
# Scraping page 34...
#   Added 20 new articles.
# Scraping page 35...
#   Added 20 new articles.
# Scraping page 36...
#   Added 20 new articles.
# Scraping page 37...
#   Added 20 new articles.
# Scraping page 38...
#   Added 20 new articles.
# Scraping page 39...
#   Added 20 new articles.
# Scraping page 40...
#   Added 20 new articles.
# Scraping page 41...
#   Added 20 new articles.
# Scraping page 42...
#   Added 20 new articles.
# Scraping page 43...
#   Added 20 new articles.
# Scraping page 44...
#   Added 20 new articles.
# Scraping page 45...
#   Added 20 new articles.
# Scraping page 46...
#   Added 20 new articles.
# Scraping page 47...
#   Added 20 new articles.
# Scraping page 48...
#   Added 20 new articles.
# Scraping page 49...
#   Added 20 new articles.
# Scraping page 50...
#   Added 20 new articles.
# Scraping page 51...
#   Added 20 new articles.
# Scraping page 52...
#   Added 20 new articles.
# Scraping page 53...
#   Added 20 new articles.
# Scraping page 54...
#   Added 20 new articles.
# Scraping page 55...
#   Added 20 new articles.
# Scraping page 56...
#   Added 20 new articles.
# Scraping page 57...
#   Added 20 new articles.
# Scraping page 58...
#   Added 20 new articles.
# Scraping page 59...
#   Added 20 new articles.
# Scraping page 60...
#   Added 20 new articles.
# Scraping page 61...
#   Added 20 new articles.
# Scraping page 62...
#   Added 20 new articles.
# Scraping page 63...
#   Added 20 new articles.
# Scraping page 64...
#   Added 20 new articles.
# Scraping page 65...
#   Added 20 new articles.
# Scraping page 66...
#   Added 20 new articles.
# Scraping page 67...
#   Added 20 new articles.
# Scraping page 68...
#   Added 20 new articles.
# Scraping page 69...
#   Added 20 new articles.
# Scraping page 70...
#   Added 20 new articles.
# Scraping page 71...
#   Added 20 new articles.
# Scraping page 72...
#   Added 20 new articles.
# Scraping page 73...
#   Added 20 new articles.
# Scraping page 74...
#   Added 20 new articles.
# Scraping page 75...
#   Added 20 new articles.
# Scraping page 76...
#   Added 20 new articles.
# Scraping page 77...
#   Added 20 new articles.
# Scraping page 78...
#   Added 20 new articles.
# Scraping page 79...
#   Added 20 new articles.
# Scraping page 80...
#   Added 20 new articles.
# Scraping page 81...
#   Added 20 new articles.
# Scraping page 82...
#   Added 20 new articles.
# Scraping page 83...
#   Added 20 new articles.
# Scraping page 84...
#   Added 20 new articles.
# Scraping page 85...
#   Added 20 new articles.
# Scraping page 86...
#   Added 20 new articles.
# Scraping page 87...
#   Added 20 new articles.
# Scraping page 88...
#   Added 20 new articles.
# Scraping page 89...
#   Added 20 new articles.
# Scraping page 90...
#   Added 20 new articles.
# Scraping page 91...
#   Added 20 new articles.
# Scraping page 92...
#   Added 20 new articles.
# Scraping page 93...
#   Added 20 new articles.
# Scraping page 94...
#   Added 20 new articles.
# Scraping page 95...
#   Added 20 new articles.
# Scraping page 96...
#   Added 20 new articles.
# Scraping page 97...
#   Added 20 new articles.
# Scraping page 98...
#   Added 20 new articles.
# Scraping page 99...
#   Added 20 new articles.
# Scraping page 100...
#   Added 20 new articles.
# Scraping page 101...
#   Added 20 new articles.
# Scraping page 102...
#   Added 20 new articles.
# Scraping page 103...
#   Added 20 new articles.
# Scraping page 104...
#   Added 20 new articles.
# Scraping page 105...
#   Added 20 new articles.
# Scraping page 106...
#   Added 20 new articles.
# Scraping page 107...
#   Added 20 new articles.
# Scraping page 108...
#   Added 20 new articles.
# Scraping page 109...
#   Added 20 new articles.
# Scraping page 110...
#   Added 20 new articles.
# Scraping page 111...
#   Added 20 new articles.
# Scraping page 112...
#   Added 20 new articles.
# Scraping page 113...
#   Added 20 new articles.
# Scraping page 114...
#   Added 20 new articles.
# Scraping page 115...
#   Added 20 new articles.
# Scraping page 116...
#   Added 20 new articles.
# Scraping page 117...
#   Added 20 new articles.
# Scraping page 118...
#   Added 20 new articles.
# Scraping page 119...
#   Added 20 new articles.
# Scraping page 120...
#   Added 20 new articles.
# Scraping page 121...
#   Added 20 new articles.
# Scraping page 122...
#   Added 20 new articles.
# Scraping page 123...
#   Added 20 new articles.
# Scraping page 124...
#   Added 20 new articles.
# Scraping page 125...
#   Added 20 new articles.
# Scraping page 126...
#   Added 20 new articles.
# Scraping page 127...
#   Added 20 new articles.
# Scraping page 128...
#   Added 20 new articles.
# Scraping page 129...
#   Added 20 new articles.
# Scraping page 130...
#   Added 20 new articles.
# Scraping page 131...
#   Added 20 new articles.
# Scraping page 132...
#   Added 20 new articles.
# Scraping page 133...
#   Added 20 new articles.
# Scraping page 134...
#   Added 20 new articles.
# Scraping page 135...
#   Added 20 new articles.
# Scraping page 136...
#   Added 20 new articles.
# Scraping page 137...
#   Added 20 new articles.
# Scraping page 138...
#   Added 20 new articles.
# Scraping page 139...
#   Added 20 new articles.
# Scraping page 140...
#   Added 20 new articles.
# Scraping page 141...
#   Added 20 new articles.
# Scraping page 142...
#   Added 20 new articles.
# Scraping page 143...
#   Added 20 new articles.
# Scraping page 144...
#   Added 20 new articles.
# Scraping page 145...
#   Added 20 new articles.
# Scraping page 146...
#   Added 20 new articles.
# Scraping page 147...
#   Added 20 new articles.
# Scraping page 148...
#   Added 20 new articles.
# Scraping page 149...
#   Added 20 new articles.
# Scraping page 150...
#   Added 20 new articles.
# Scraping page 151...
#   Added 20 new articles.
# Scraping page 152...
#   Added 20 new articles.
# Scraping page 153...
#   Added 20 new articles.
# Scraping page 154...
#   Added 20 new articles.
# Scraping page 155...
#   Added 20 new articles.
# Scraping page 156...
#   Added 20 new articles.
# Scraping page 157...
#   Added 20 new articles.
# Scraping page 158...
#   Added 20 new articles.
# Scraping page 159...
#   Added 20 new articles.
# Scraping page 160...
#   Added 20 new articles.
# Scraping page 161...
#   Added 20 new articles.
# Scraping page 162...
#   Added 20 new articles.
# Scraping page 163...
#   Added 20 new articles.
# Scraping page 164...
#   Added 20 new articles.
# Scraping page 165...
#   Added 20 new articles.
# Scraping page 166...
#   Added 20 new articles.
# Scraping page 167...
#   Added 20 new articles.
# Scraping page 168...
#   Added 20 new articles.
# Scraping page 169...
#   Added 20 new articles.
# Scraping page 170...
#   Added 20 new articles.
# Scraping page 171...
#   Added 20 new articles.
# Scraping page 172...
#   Added 20 new articles.
# Scraping page 173...
#   Added 20 new articles.
# Scraping page 174...
#   Added 20 new articles.
# Scraping page 175...
#   Added 20 new articles.
# Scraping page 176...
#   Added 20 new articles.
# Scraping page 177...
#   Added 20 new articles.
# Scraping page 178...
#   Added 20 new articles.
# Scraping page 179...
#   Added 20 new articles.
# Scraping page 180...
#   Added 20 new articles.
# Scraping page 181...
#   Added 20 new articles.
# Scraping page 182...
#   Added 20 new articles.
# Scraping page 183...
#   Added 20 new articles.
# Scraping page 184...
#   Added 20 new articles.
# Scraping page 185...
#   Added 20 new articles.
# Scraping page 186...
#   Added 20 new articles.
# Scraping page 187...
#   Added 20 new articles.
# Scraping page 188...
#   Added 20 new articles.
# Scraping page 189...
#   Added 20 new articles.
# Scraping page 190...
#   Added 20 new articles.
# Scraping page 191...
#   Added 20 new articles.
# Scraping page 192...
#   Added 20 new articles.
# Scraping page 193...
#   Added 20 new articles.
# Scraping page 194...
#   Added 20 new articles.
# Scraping page 195...
#   Added 20 new articles.
# Scraping page 196...
#   Added 20 new articles.
# Scraping page 197...
#   Added 20 new articles.
# Scraping page 198...
#   Added 20 new articles.
# Scraping page 199...
#   Added 20 new articles.
# Scraping page 200...
#   Added 20 new articles.
# Scraping page 201...
#   Added 20 new articles.
# Scraping page 202...
#   Added 20 new articles.
# Scraping page 203...
#   Added 20 new articles.
# Scraping page 204...
#   Added 20 new articles.
# Scraping page 205...
#   Added 20 new articles.
# Scraping page 206...
#   Added 20 new articles.
# Scraping page 207...
#   Added 20 new articles.
# Scraping page 208...
#   Added 20 new articles.
# Scraping page 209...
#   Added 20 new articles.
# Scraping page 210...
#   Added 20 new articles.
# Scraping page 211...
#   Added 20 new articles.
# Scraping complete.

# %%
# Verification & Visualization
conn = sqlite3.connect(DB_NAME)
df = pd.read_sql_query("SELECT * FROM announcements", conn)
conn.close()

print(f"Total articles in database: {len(df)}")
print(df.head())
# Out:
# Total articles in database: 4220
#    id                                              title        date  \
# 0   1  ICANN Extends Deadline for Expressions of Inte...  2026-04-20
# 1   2  ICANN to Host Question-and-Answer Sessions for...  2026-04-13
# 2   3  ICANN Request for Proposal: Global Payroll Ser...  2026-04-10
# 3   4  Preview the ICANN FY27–31 Operating and Financ...  2026-04-06
# 4   5  ICANN Issues Request for Proposal: 2026 Round ...  2026-04-01
#
#                                                 link content
# 0  https://www.icann.org/en/announcements/details...    None
# 1  https://www.icann.org/en/announcements/details...    None
# 2  https://www.icann.org/en/announcements/details...    None
# 3  https://www.icann.org/en/announcements/details...    None
# 4  https://www.icann.org/en/announcements/details...    None

# %%
# Convert date to datetime
df['date_obj'] = pd.to_datetime(df['date'])
df['year_month'] = df['date_obj'].dt.to_period('M').astype(str)

# Timeline Chart
timeline_counts = df.groupby('year_month').size().reset_index(name='count')
fig = px.bar(timeline_counts, x='year_month', y='count', title='ICANN Announcements Over Time')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ae2a04c1-86ff-4916-957f-cc7ed3b21630" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae2a04c1-86ff-4916-957f-cc7ed3b21630")) {                    Plotly.newPlot(                        "ae2a04c1-86ff-4916-957f-cc7ed3b21630",                        [{"alignmentgroup":"True","hovertemplate":"year_month=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2000-02","2000-04","2000-05","2000-06","2000-07","2000-08","2000-09","2000-10","2000-11","2000-12","2001-01","2001-02","2001-03","2001-04","2001-05","2001-06","2001-07","2001-08","2001-09","2001-10","2001-11","2001-12","2002-01","2002-02","2002-03","2002-04","2002-05","2002-06","2002-07","2002-08","2002-09","2002-10","2002-11","2002-12","2003-01","2003-02","2003-03","2003-04","2003-05","2003-06","2003-07","2003-08","2003-09","2003-10","2003-11","2003-12","2004-02","2004-03","2004-04","2004-05","2004-06","2004-07","2004-08","2004-09","2004-10","2004-11","2004-12","2005-01","2005-02","2005-03","2005-04","2005-05","2005-06","2005-07","2005-08","2005-09","2005-10","2005-11","2005-12","2006-01","2006-02","2006-03","2006-04","2006-05","2006-06","2006-07","2006-08","2006-09","2006-10","2006-11","2006-12","2007-01","2007-02","2007-03","2007-04","2007-05","2007-06","2007-07","2007-08","2007-09","2007-10","2007-11","2007-12","2008-01","2008-02","2008-03","2008-04","2008-05","2008-06","2008-07","2008-08","2008-09","2008-10","2008-11","2008-12","2009-01","2009-02","2009-03","2009-04","2009-05","2009-06","2009-07","2009-08","2009-09","2009-10","2009-11","2009-12","2010-01","2010-02","2010-03","2010-04","2010-05","2010-06","2010-07","2010-08","2010-09","2010-10","2010-11","2010-12","2011-01","2011-02","2011-03","2011-04","2011-05","2011-06","2011-07","2011-08","2011-09","2011-10","2011-11","2011-12","2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09","2018-10","2018-11","2018-12","2019-01","2019-02","2019-03","2019-04","2019-05","2019-06","2019-07","2019-08","2019-09","2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12","2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08","2023-09","2023-10","2023-11","2023-12","2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09","2025-10","2025-11","2025-12","2026-01","2026-02","2026-03","2026-04"],"xaxis":"x","y":[2,2,6 ...

# %%
# Word Cloud (Treemap approximation)
# Simple word frequency count
from collections import Counter
import re

all_text = ' '.join(df['title'].tolist())
words = re.findall(r'\w+', all_text.lower())
stop_words = {'icann', 'the', 'to', 'of', 'and', 'in', 'for', 'on', 'a', 'with', 'is', 'be', 'as', 'by', 'an', 'at', 'from'}
filtered_words = [w for w in words if w not in stop_words and len(w) > 2]
word_counts = Counter(filtered_words)

# Top 50 words
top_words = pd.DataFrame(word_counts.most_common(50), columns=['word', 'count'])
fig_wc = px.treemap(top_words, path=['word'], values='count', title='Top Words in ICANN Announcements')
fig_wc.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6f05d180-1c4e-4655-90e1-2c73c96a1966" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f05d180-1c4e-4655-90e1-2c73c96a1966")) {                    Plotly.newPlot(                        "6f05d180-1c4e-4655-90e1-2c73c96a1966",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["announces","application","available","board","call","cctld","comment","committee","community","data","dns","domain","draft","fellowship","final","generation","global","gnso","group","gtld","iana","idn","interest","internet","meeting","name","names","new","nominating","now","open","operating","plan","policy","process","program","proposal","proposed","public","publishes","registry","report","request","review","root","seeks","update","webinar","whois","zone"],"labels":["announces","application","available","board","call","cctld","comment","committee","community","data","dns","domain","draft","fellowship","final","generation","global","gnso","group","gtld","iana","idn","interest","internet","meeting","name","names","new","nominating","now","open","operating","plan","policy","process","program","proposal","proposed","public","publishes","registry","report","request","review","root","seeks","update","webinar","whois","zone"],"name":"","parents":["","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",""],"values":[190,123,145,213,195,116,329,205,249,152,130,206,224,121,121,115,124,145,153,219,114,151,120,277,260,130,164,419,124,245,126,143,191,247,182,205,161,236,475,127,148,414,188,310,168,121,212,148,122,114],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33 ...
