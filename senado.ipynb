# %%
# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import sqlite3
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"

# %%
# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

BASE_URL = "https://www12.senado.leg.br/noticias/ultimas"
DATABASE_NAME = "internet_governance_news.db"

print("Scraper Senado Notícias pronto!")
# Out:
# Scraper Senado Notícias pronto!

# %%
# %%
def create_database():
    conn = sqlite3.connect(DATABASE_NAME)
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS articles (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            title TEXT,
            date TEXT,
            author TEXT,
            url TEXT UNIQUE,
            source TEXT
        )
    """)
    conn.commit()
    conn.close()
    print("✅ Banco e tabela prontos")

create_database()
# Out:
# ✅ Banco e tabela prontos

# %%
# %%
def insert_article(title, date, author, url, source):
    conn = sqlite3.connect(DATABASE_NAME)
    cursor = conn.cursor()
    try:
        cursor.execute("""
            INSERT INTO articles (title, date, author, url, source)
            VALUES (?, ?, ?, ?, ?)
        """, (title, date, author, url, source))
        conn.commit()
        return True
    except sqlite3.IntegrityError:
        return False
    finally:
        conn.close()

# %%
# %%
def montar_url(pagina):
    if pagina == 1:
        return BASE_URL
    return f"{BASE_URL}/{pagina}"

# %%
# %%
noticias = []
TOTAL_PAGES = 2719
inserted = 0

for pagina in range(TOTAL_PAGES, 0, -1):
    url = montar_url(pagina)
    print(f"Coletando página {pagina}: {url}")

    r = requests.get(url, headers=HEADERS, timeout=15)
    if r.status_code != 200:
        continue

    soup = BeautifulSoup(r.text, "html.parser")
    lista = soup.find("ol", class_="lista-resultados")
    if not lista:
        continue

    itens = lista.find_all("li", recursive=False)
    print(f"  {len(itens)} notícias encontradas")

    for item in itens:
        titulo_tag = item.find("span", class_="eta")
        link_tag = item.find("a", href=True)
        data_tag = item.select_one("div.text-muted.normalis")

        if not titulo_tag or not link_tag:
            continue

        link = link_tag["href"]
        if link.startswith("/"):
            link = "https://www12.senado.leg.br" + link

        titulo = titulo_tag.get_text(strip=True)
        data = data_tag.get_text(strip=True) if data_tag else "NA"

        if insert_article(
            title=titulo,
            date=data,
            author="Agência Senado",
            url=link,
            source="Agência Senado"
        ):
            inserted += 1

        noticias.append({
            "titulo": titulo,
            "data": data,
            "link": link,
            "pagina": pagina
        })

    time.sleep(1)

print(f"\n📥 Total de novas notícias inseridas no banco: {inserted}")
# Out:
# Coletando página 5: https://www12.senado.leg.br/noticias/ultimas/5
#   20 notícias encontradas
# Coletando página 4: https://www12.senado.leg.br/noticias/ultimas/4
#   20 notícias encontradas
# Coletando página 3: https://www12.senado.leg.br/noticias/ultimas/3
#   20 notícias encontradas
# Coletando página 2: https://www12.senado.leg.br/noticias/ultimas/2
#   20 notícias encontradas
# Coletando página 1: https://www12.senado.leg.br/noticias/ultimas
#   20 notícias encontradas
#
# 📥 Total de novas notícias inseridas no banco: 2

# %%
def load_articles():
    conn = sqlite3.connect(DATABASE_NAME)
    df = pd.read_sql("""
        SELECT * FROM articles
        ORDER BY date DESC
    """, conn)
    conn.close()
    return df

df_db = load_articles()
print(f"📦 Total no banco: {len(df_db)} registros")
display(df_db.head(20))
# Out:
# 📦 Total no banco: 3523 registros
#       id                                              title              date  \
# 0   3578  Câmara divulga Relatório de Participação Popul...  31/12/2024 09:49
# 1   3510  Câmara divulga resultado de concurso de vídeos...  31/10/2024 11:01
# 2   3785  Congresso se ilumina na cor laranja em apoio à...  31/07/2025 15:07
# 3   3389  Projeto sobre aborto é o destaque da participa...  31/07/2024 16:57
# 4   3390  Programa da Câmara voltado ao público infantoj...  31/07/2024 11:59
# 5   4071                          Dúvidas sobre as eleições  31/07/2006 00h00
# 6   4009                                          Tabagismo  31/05/2004 00h00
# 7   3644  Autor da mostra "A cidade se perde nas ausênci...  31/03/2025 09:08
# 8   3194  Visitação institucional ao Congresso fica susp...  31/01/2024 15:04
# 9   3195  Medalha do Mérito Legislativo de 2023 será ent...  31/01/2024 11:50
# 10  4129  Responsabilidades e prerrogativas da Presidênc...  31/01/2007 23h00
# 11   683  Em duas décadas, proporção de lares urbanos br...       31 OUT 2024
# 12  1374  CGI.br busca saídas para o acesso mundial à re...       31 OUT 2007
# 13  1399  ICANN 2006 debate no Brasil as tendências da i...       31 OUT 2006
# 14   797  No FIB13, especialistas apontam expectativas e...       31 MAI 2023
# 15  1140                                  TIC Empresas 2013       31 MAI 2014
# 16  1267               CGI.br apresenta TIC Domicílios 2011       31 MAI 2012
# 17  1411  Comitê Gestor da Internet no Brasil comemora d...       31 MAI 2005
# 18  1412  Comitê Gestor     da Internet no Brasil comemo...       31 MAI 2005
# 19  1428  O terceiro milênio - Passado e futuro na virad...       31 DEZ 2000
#
#              author                                                url  \
# 0    Agência Câmara  https://www.camara.leg.br/assessoria-de-impren...
# 1    Agência Câmara  https://www.camara.leg.br/assessoria-de-impren...
# 2    Agência Câmara  https://www.camara.leg.br/assessoria-de-impren...
# 3    Agência Câmara  https://www.camara.leg.br/assessoria-de-impren...
# 4    Agência Câmara  https://www.camara.leg.br/assessoria-de-impren...
# 5    Agência Senado  https://www12.senado.leg.br/noticias/especiais...
# 6    Agência Senado  https://www12.senado.leg.br/noticias/especiais...
# 7    Agência Câmara  https://www.camara.leg.br/assessoria-de-impren...
# 8    Agência Câmara  https://www.camara.leg.br/assessoria-de-impren...
# 9    Agência Câmara  https://www.camara.leg.br/assessoria-de-impren...
# 10   Agência Senado  https://www12.senado.leg.br/noticias/especiais...
# 11  CGI.br Notícias  https://cgi.br/noticia/releases/em-duas-decada...
# 12  CGI.br Notícias  https://cgi.br/noticia/releases/cgi-br-busca-s...
# 13  CGI.br Notícias  https://cgi.br/noticia/releases/icann-2006-deb...
# 14  CGI.br Notícias  https://cgi.br/noticia/releases/no-fib-13-espe...
# 15  CGI.br Notícias    https://cgi.br/noticia/notas/tic-empresas-2013/
# 16  CGI.br Notícias  https://cgi.br/noticia/releases/cgi-br-apresen...
# 17  CGI.br Notícias  https://cgi.br/noticia/releases/comite-gestor-...
# 18  CGI.br Notícias  https://cgi.br/noticia/coletivas/comite-gestor...
# 19  CGI.br Notícias  https://cgi.br/noticia/releases/o-terceiro-mil...
#
#                   source
# 0   Câmara dos Deputados
# 1   Câmara dos Deputados
# 2   Câmara dos Deputados
# 3   Câmara dos Deputados
# 4   Câmara dos Deputados
# 5         Agência Senado
# 6         Agência Senado
# 7   Câmara dos Deputados
# 8   Câmara dos Deputados
# 9   Câmara dos Deputados
# 10        Agência Senado
# 11          CGI Notícias
# 12          CGI Notícias
# 13          CGI Notícias
# 14          CGI Notícias
# 15          CGI Notícias
# 16          CGI Notícias
# 17          CGI Notícias
# 18          CGI Notícias
# 19          CGI Notícias

# %%
def plot_charts(df):
    if df.empty:
        print("❌ Sem dados para gráficos")
        return
    
    top15 = df.head(15).copy()
    top15['rank'] = range(1, len(top15) + 1)

    fig1 = px.bar(
        top15,
        x='rank',
        y='title',
        orientation='h',
        title='Top 15 Notícias – Internet Governance'
    )
    fig1.update_layout(height=600)
    fig1.show()

    source_count = df["source"].value_counts().reset_index()
    source_count.columns = ["source", "count"]

    fig2 = px.pie(
        source_count,
        names="source",
        values="count",
        title="Distribuição por Fonte"
    )
    fig2.show()


    text = ' '.join(df['title'].astype(str)).lower()
    words = re.findall(r'\b\w{4,}\b', text)

    wc = (
        pd.Series(words)
        .value_counts()
        .head(20)
        .reset_index()
    )
    wc.columns = ['palavra', 'freq']

    fig3 = px.treemap(
        wc,
        path=['palavra'],
        values='freq',
        title='Nuvem de Palavras – Títulos'
    )
    fig3.show()

# %%
# %%
plot_charts_db(df_db)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="8cd7a399-aa83-4ed7-9098-c114049b962d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8cd7a399-aa83-4ed7-9098-c114049b962d")) {                    Plotly.newPlot(                        "8cd7a399-aa83-4ed7-9098-c114049b962d",                        [{"hovertemplate":"rank=%{x}\u003cbr\u003etitle=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCgsMDQ4P"},"xaxis":"x","y":["C\u00e2mara divulga Relat\u00f3rio de Participa\u00e7\u00e3o Popular de dezembro","C\u00e2mara divulga resultado de concurso de v\u00eddeos sobre viol\u00eancia contra a mulher","Congresso se ilumina na cor laranja em apoio \u00e0 conscientiza\u00e7\u00e3o sobre o TDAH","Projeto sobre aborto \u00e9 o destaque da participa\u00e7\u00e3o popular em junho","Programa da C\u00e2mara voltado ao p\u00fablico infantojuvenil celebra 20 anos com evento especial","D\u00favidas sobre as elei\u00e7\u00f5es","Tabagismo","Autor da mostra \"A cidade se perde nas aus\u00eancias\" participa de bate-papo com o p\u00fablico nesta quinta (3)","Visita\u00e7\u00e3o institucional ao Congresso fica suspensa de 2 a 6 de fevereiro","Medalha do M\u00e9rito Legislativo de 2023 ser\u00e1 entregue na quarta-feira (7)","Responsabilidades e prerrogativas da Presid\u00eancia e da Mesa","Em duas d\u00e9cadas, propor\u00e7\u00e3o de lares urbanos brasileiros com Internet passou de 13% para 85%, aponta TIC Domic\u00edlios 2024","CGI.br busca sa\u00eddas para o acesso mundial \u00e0 rede no IGF Brazil 2007","ICANN 2006 debate no Brasil as tend\u00eancias da internet","No FIB13, especialistas apontam expectativas e preocupa\u00e7\u00f5es em rela\u00e7\u00e3o ao Pacto Digital Global, da ONU"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""} ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="83689085-09a1-4c82-9918-896714ea50b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("83689085-09a1-4c82-9918-896714ea50b3")) {                    Plotly.newPlot(                        "83689085-09a1-4c82-9918-896714ea50b3",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"source=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["European Commission","CGI Not\u00edcias","C\u00e2mara dos Deputados","NIC Not\u00edcias","Senado Federal","Ag\u00eancia Senado","CGI Reuni\u00f5es"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i2","bdata":"gwNEAwoD8wFJAawACgA="},"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlin ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="26306057-5a31-413a-817f-fe91e67d8d9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("26306057-5a31-413a-817f-fe91e67d8d9e")) {                    Plotly.newPlot(                        "26306057-5a31-413a-817f-fe91e67d8d9e",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003efreq=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["para","internet","sobre","c\u00e2mara","brasil","congresso","digital","european","nacional","commission","recebe","pelo","debate","lan\u00e7a","f\u00f3rum","ilumina\u00e7\u00e3o","rules","governan\u00e7a","dados","anos"],"labels":["para","internet","sobre","c\u00e2mara","brasil","congresso","digital","european","nacional","commission","recebe","pelo","debate","lan\u00e7a","f\u00f3rum","ilumina\u00e7\u00e3o","rules","governan\u00e7a","dados","anos"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":{"dtype":"f8","bdata":"AAAAAACogUAAAAAAAPB7QAAAAAAA8HdAAAAAAACQd0AAAAAAANB0QAAAAAAAEHFAAAAAAACgZkAAAAAAAGBjQAAAAAAAwF9AAAAAAAAAXUAAAAAAAABdQAAAAAAAAFxAAAAAAADAWkAAAAAAAABaQAAAAAAAQFhAAAAAAABAWEAAAAAAAEBVQAAAAAAAQFRAAAAAAADAU0AAAAAAAMBTQA=="},"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type ...
