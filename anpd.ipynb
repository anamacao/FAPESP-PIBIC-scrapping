# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3
import time
import re

import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
DATABASE_NAME = "internet_governance_news.db"

def create_database():
    conn = sqlite3.connect(DATABASE_NAME)
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS articles (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            title TEXT,
            date TEXT,
            author TEXT,
            url TEXT UNIQUE,
            source TEXT
        )
    """)
    conn.commit()
    conn.close()
    print("✅ Banco e tabela 'articles' prontos!")

create_database()
# Out:
# ✅ Banco e tabela 'articles' prontos!

# %%
def insert_article(title, date, author, url, source):
    conn = sqlite3.connect(DATABASE_NAME)
    cursor = conn.cursor()
    try:
        cursor.execute("""
            INSERT INTO articles (title, date, author, url, source)
            VALUES (?, ?, ?, ?, ?)
        """, (title, date, author, url, source))
        conn.commit()
        return True
    except sqlite3.IntegrityError:
        return False
    finally:
        conn.close()

# %%
def montar_url(pagina):
    if pagina == 1:
        return "https://www12.senado.leg.br/noticias/ultimas"
    return f"https://www12.senado.leg.br/noticias/ultimas/{pagina}"

# %%
noticias = []

for pagina in range(18, 0, -1):
    url = montar_url(pagina)
    print(f"📄 Coletando página {pagina}: {url}")

    r = requests.get(url, timeout=10)
    soup = BeautifulSoup(r.text, "html.parser")

    lista = soup.find("ol", class_="lista-resultados")
    if not lista:
        print("⚠️ Nenhuma lista encontrada")
        continue

    itens = lista.find_all("li")
    print(f"   {len(itens)} notícias encontradas")

    for item in itens:
        titulo_tag = item.find("span", class_="eta")
        link_tag = item.find("a")
        data_tag = item.select_one("div.text-muted.normalis")

        if not titulo_tag or not link_tag:
            continue

        data = {
            "title": titulo_tag.get_text(strip=True),
            "date": data_tag.get_text(strip=True) if data_tag else None,
            "author": "Agência Senado",
            "url": "https://www12.senado.leg.br" + link_tag["href"],
            "source": "Senado Federal"
        }

        noticias.append(data)
        insert_article(**data)

    time.sleep(1)

print(f"\n✅ Total coletado: {len(noticias)} notícias")
df_senado = pd.DataFrame(noticias)
display(df_senado.head())
# Out:
# 📄 Coletando página 18: https://www12.senado.leg.br/noticias/ultimas/18
#    20 notícias encontradas
# 📄 Coletando página 17: https://www12.senado.leg.br/noticias/ultimas/17
#    20 notícias encontradas
# 📄 Coletando página 16: https://www12.senado.leg.br/noticias/ultimas/16
#    20 notícias encontradas
# 📄 Coletando página 15: https://www12.senado.leg.br/noticias/ultimas/15
#    20 notícias encontradas
# 📄 Coletando página 14: https://www12.senado.leg.br/noticias/ultimas/14
#    20 notícias encontradas
# 📄 Coletando página 13: https://www12.senado.leg.br/noticias/ultimas/13
#    20 notícias encontradas
# 📄 Coletando página 12: https://www12.senado.leg.br/noticias/ultimas/12
#    20 notícias encontradas
# 📄 Coletando página 11: https://www12.senado.leg.br/noticias/ultimas/11
#    20 notícias encontradas
# 📄 Coletando página 10: https://www12.senado.leg.br/noticias/ultimas/10
#    20 notícias encontradas
# 📄 Coletando página 9: https://www12.senado.leg.br/noticias/ultimas/9
#    20 notícias encontradas
# 📄 Coletando página 8: https://www12.senado.leg.br/noticias/ultimas/8
#    20 notícias encontradas
# 📄 Coletando página 7: https://www12.senado.leg.br/noticias/ultimas/7
#    20 notícias encontradas
# 📄 Coletando página 6: https://www12.senado.leg.br/noticias/ultimas/6
#    20 notícias encontradas
# 📄 Coletando página 5: https://www12.senado.leg.br/noticias/ultimas/5
#    20 notícias encontradas
# 📄 Coletando página 4: https://www12.senado.leg.br/noticias/ultimas/4
#    20 notícias encontradas
# 📄 Coletando página 3: https://www12.senado.leg.br/noticias/ultimas/3
#    20 notícias encontradas
# 📄 Coletando página 2: https://www12.senado.leg.br/noticias/ultimas/2
#    20 notícias encontradas
# 📄 Coletando página 1: https://www12.senado.leg.br/noticias/ultimas
#    20 notícias encontradas
#
# ✅ Total coletado: 329 notícias
#                                                title              date  \
# 0  Avança proposta de criação de exame nacional o...  03/12/2025 13h21
# 1  Cleitinho defende Michelle em polêmica sobre a...  03/12/2025 12h28
# 2    CCJ aprova regras para testamento de emergência  03/12/2025 12h12
# 3  Agora é lei: doação de medicamentos será isent...  03/12/2025 11h37
# 4  Vai ao Plenário PEC que amplia acúmulo de carg...  03/12/2025 10h55
#
#            author                                                url  \
# 0  Agência Senado  https://www12.senado.leg.br/noticias/materias/...
# 1  Agência Senado  https://www12.senado.leg.br/noticias/materias/...
# 2  Agência Senado  https://www12.senado.leg.br/noticias/materias/...
# 3  Agência Senado  https://www12.senado.leg.br/noticias/materias/...
# 4  Agência Senado  https://www12.senado.leg.br/noticias/materias/...
#
#            source
# 0  Senado Federal
# 1  Senado Federal
# 2  Senado Federal
# 3  Senado Federal
# 4  Senado Federal

# %%
def load_articles():
    conn = sqlite3.connect(DATABASE_NAME)
    df = pd.read_sql("""
        SELECT * FROM articles
        ORDER BY date DESC
    """, conn)
    conn.close()
    return df

df_db = load_articles()
print(f"📦 Total no banco: {len(df_db)} registros")
display(df_db.head(20))
# Out:
# 📦 Total no banco: 2573 registros
#       id                                              title         date  \
# 0    683  Em duas décadas, proporção de lares urbanos br...  31 OUT 2024
# 1   1374  CGI.br busca saídas para o acesso mundial à re...  31 OUT 2007
# 2   1399  ICANN 2006 debate no Brasil as tendências da i...  31 OUT 2006
# 3    797  No FIB13, especialistas apontam expectativas e...  31 MAI 2023
# 4   1140                                  TIC Empresas 2013  31 MAI 2014
# 5   1267               CGI.br apresenta TIC Domicílios 2011  31 MAI 2012
# 6   1411  Comitê Gestor da Internet no Brasil comemora d...  31 MAI 2005
# 7   1412  Comitê Gestor     da Internet no Brasil comemo...  31 MAI 2005
# 8   1428  O terceiro milênio - Passado e futuro na virad...  31 DEZ 2000
# 9    880  Dificuldade dos pais para apoiar alunos e falt...  31 AGO 2021
# 10   621  Mais acessível e completo: conheça o novo site...  30 SET 2025
# 11   622  Evento em São Paulo celebra 15 anos de SACI-Ad...  30 SET 2025
# 12   999  VIII Fórum da Internet amplia discussões sobre...  30 OUT 2018
# 13  1180  Comissão Eleitoral do CGI.br divulga lista de ...  30 OUT 2013
# 14  1325  CGI.br apoia Seminário Cidadania e Redes Digitais  30 OUT 2009
# 15  1375                      NIC.br traz W3C para o Brasil  30 OUT 2007
# 16  1376  CGI.br e ONU receberão mais de mil participant...  30 OUT 2007
# 17   798  Abertas as inscrições para o 13º Fórum da Inte...  30 MAI 2023
# 18   858  Conselheiros do CGI.br visitam instalações do ...  30 MAI 2022
# 19  1166                     Dilma Rousseff discursa na ONU  30 DEZ 2013
#
#              author                                                url  \
# 0   CGI.br Notícias  https://cgi.br/noticia/releases/em-duas-decada...
# 1   CGI.br Notícias  https://cgi.br/noticia/releases/cgi-br-busca-s...
# 2   CGI.br Notícias  https://cgi.br/noticia/releases/icann-2006-deb...
# 3   CGI.br Notícias  https://cgi.br/noticia/releases/no-fib-13-espe...
# 4   CGI.br Notícias    https://cgi.br/noticia/notas/tic-empresas-2013/
# 5   CGI.br Notícias  https://cgi.br/noticia/releases/cgi-br-apresen...
# 6   CGI.br Notícias  https://cgi.br/noticia/releases/comite-gestor-...
# 7   CGI.br Notícias  https://cgi.br/noticia/coletivas/comite-gestor...
# 8   CGI.br Notícias  https://cgi.br/noticia/releases/o-terceiro-mil...
# 9   CGI.br Notícias  https://cgi.br/noticia/releases/dificuldade-do...
# 10  CGI.br Notícias  https://cgi.br/noticia/notas/mais-acessivel-e-...
# 11  CGI.br Notícias  https://cgi.br/noticia/releases/evento-em-sao-...
# 12  CGI.br Notícias  https://cgi.br/noticia/releases/viii-forum-da-...
# 13  CGI.br Notícias  https://cgi.br/noticia/releases/comissao-eleit...
# 14  CGI.br Notícias  https://cgi.br/noticia/releases/cgi-br-apoia-s...
# 15  CGI.br Notícias  https://cgi.br/noticia/releases/nic-br-traz-w3...
# 16  CGI.br Notícias  https://cgi.br/noticia/releases/cgi-br-e-onu-r...
# 17  CGI.br Notícias  https://cgi.br/noticia/releases/abertas-as-ins...
# 18  CGI.br Notícias  https://cgi.br/noticia/notas/conselheiros-do-c...
# 19  CGI.br Notícias  https://cgi.br/noticia//dilma-rousseff-discurs...
#
#           source
# 0   CGI Notícias
# 1   CGI Notícias
# 2   CGI Notícias
# 3   CGI Notícias
# 4   CGI Notícias
# 5   CGI Notícias
# 6   CGI Notícias
# 7   CGI Notícias
# 8   CGI Notícias
# 9   CGI Notícias
# 10  CGI Notícias
# 11  CGI Notícias
# 12  CGI Notícias
# 13  CGI Notícias
# 14  CGI Notícias
# 15  CGI Notícias
# 16  CGI Notícias
# 17  CGI Notícias
# 18  CGI Notícias
# 19  CGI Notícias

# %%
def plot_charts(df):
    if df.empty:
        print("❌ Sem dados para plotar")
        return

    # Top 15
    top15 = df.head(15).copy()
    top15["rank"] = range(1, len(top15) + 1)

    fig1 = px.bar(
        top15,
        x="rank",
        y="title",
        orientation="h",
        title="Top 15 Notícias – Internet Governance"
    )
    fig1.update_layout(height=600)
    fig1.show()

    # Fonte
    source_count = df["source"].value_counts().reset_index()
    source_count.columns = ["source", "count"]

    fig2 = px.pie(
        source_count,
        names="source",
        values="count",
        title="Distribuição por Fonte"
    )
    fig2.show()

    # Palavras
    text = " ".join(df["title"].astype(str)).lower()
    words = re.findall(r"\b\w{4,}\b", text)

    word_freq = (
        pd.Series(words)
        .value_counts()
        .head(20)
        .reset_index()
    )
    word_freq.columns = ["palavra", "freq"]

    fig3 = px.treemap(
        word_freq,
        path=["palavra"],
        values="freq",
        title="Palavras mais frequentes nos títulos"
    )
    fig3.show()

# %%
plot_charts(df_db)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="42813664-2f5c-4aab-87f0-2a7fb30bd57f" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("42813664-2f5c-4aab-87f0-2a7fb30bd57f")) {                    Plotly.newPlot(                        "42813664-2f5c-4aab-87f0-2a7fb30bd57f",                        [{"hovertemplate":"rank=%{x}\u003cbr\u003etitle=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCgsMDQ4P"},"xaxis":"x","y":["Em duas d\u00e9cadas, propor\u00e7\u00e3o de lares urbanos brasileiros com Internet passou de 13% para 85%, aponta TIC Domic\u00edlios 2024","CGI.br busca sa\u00eddas para o acesso mundial \u00e0 rede no IGF Brazil 2007","ICANN 2006 debate no Brasil as tend\u00eancias da internet","No FIB13, especialistas apontam expectativas e preocupa\u00e7\u00f5es em rela\u00e7\u00e3o ao Pacto Digital Global, da ONU","TIC Empresas 2013","CGI.br apresenta TIC Domic\u00edlios 2011","Comit\u00ea Gestor da Internet no Brasil comemora dez anos","Comit\u00ea Gestor     da Internet no Brasil comemora dez anos - 31\u002f05\u002f2005","O terceiro mil\u00eanio - Passado e futuro na virada do mil\u00eanio","Dificuldade dos pais para apoiar alunos e falta de acesso \u00e0 Internet foram desafios para ensino remoto, aponta pesquisa TIC Educa\u00e7\u00e3o","Mais acess\u00edvel e completo: conhe\u00e7a o novo site do Cetic.br","Evento em S\u00e3o Paulo celebra 15 anos de SACI-Adm, refer\u00eancia na disputa de dom\u00ednios de Internet no Brasil","VIII F\u00f3rum da Internet amplia discuss\u00f5es sobre desafios da rede","Comiss\u00e3o Eleitoral do CGI.br divulga lista de entidades aprovadas para compor o col\u00e9gio eleitoral de 2013","CGI.br apoia Semin\u00e1rio Cidadania e Redes Digitais"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth": ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="fd8928e0-24fa-4b21-9e8f-4f1148974a2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fd8928e0-24fa-4b21-9e8f-4f1148974a2b")) {                    Plotly.newPlot(                        "fd8928e0-24fa-4b21-9e8f-4f1148974a2b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"source=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["European Commission","CGI Not\u00edcias","NIC Not\u00edcias","Senado Federal","CGI Reuni\u00f5es"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i2","bdata":"gwNEA\u002fMBSQEKAA=="},"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"sc ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="dc7f7c82-4683-4b0a-ab5f-4c4220cdae7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dc7f7c82-4683-4b0a-ab5f-4c4220cdae7d")) {                    Plotly.newPlot(                        "dc7f7c82-4683-4b0a-ab5f-4c4220cdae7d",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003efreq=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["internet","para","brasil","sobre","digital","european","commission","debate","f\u00f3rum","rules","governan\u00e7a","pesquisa","europe","dados","crian\u00e7as","lan\u00e7a","ukraine","redes","online","educa\u00e7\u00e3o"],"labels":["internet","para","brasil","sobre","digital","european","commission","debate","f\u00f3rum","rules","governan\u00e7a","pesquisa","europe","dados","crian\u00e7as","lan\u00e7a","ukraine","redes","online","educa\u00e7\u00e3o"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":{"dtype":"f8","bdata":"AAAAAADQe0AAAAAAALB4QAAAAAAAoHNAAAAAAAAAb0AAAAAAAIBlQAAAAAAAYGNAAAAAAAAAXUAAAAAAAIBYQAAAAAAAAFdAAAAAAABAVUAAAAAAAEBUQAAAAAAAwFJAAAAAAABAUkAAAAAAAMBRQAAAAAAAgFFAAAAAAACAT0AAAAAAAIBOQAAAAAAAgE5AAAAAAAAATkAAAAAAAIBNQA=="},"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"ty ...
